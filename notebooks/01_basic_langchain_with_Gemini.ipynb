# %%
# Langchain Model - Gemini AI - 
# DOTENV

# %% [markdown]
# ### Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
prompts=[
    ("system","You are a helpful assistant."),
    ("user","Explain Prompts and it types In GenAI LLM."),
]
# res=llm.invoke("Explain the theory of relativity in simple terms.")
res=llm.invoke(prompts)
print(res.content)
# Out:
# In the realm of Generative AI (GenAI), particularly with Large Language Models (LLMs), a **Prompt** is the primary means of communication between a human user and the AI model. It's essentially the input, instruction, question, or context provided to the LLM to guide its generation of a response.
#
# Think of it as giving a highly intelligent, but often directionless, assistant a specific task or question. The quality and specificity of your prompt directly influence the quality and relevance of the AI's output.
#
# ## What is a Prompt in GenAI LLM?
#
# A prompt is a piece of text (or sometimes a combination of text and other data like images in multimodal models) that serves as an instruction or query for a Generative AI model. Its purpose is to:
#
# 1.  **Direct the Model:** Tell the LLM what kind of output is expected.
# 2.  **Provide Context:** Give the LLM necessary background information to generate a relevant response.
# 3.  **Specify Format:** Instruct the LLM on how the output should be structured (e.g., bullet points, JSON, a paragraph).
# 4.  **Influence Style/Tone:** Guide the LLM to respond in a particular voice or style (e.g., formal, casual, creative, technical).
# 5.  **Set Constraints:** Define limitations or rules for the generation process.
#
# The art and science of crafting effective prompts are known as **Prompt Engineering**.
#
# ---
#
# ## Types of Prompts in GenAI LLM
#
# Prompts can be categorized based on their structure, the type of information they provide, and the intended outcome. Here are some common types:
#
# ### 1. Direct Instruction Prompts
# These are the simplest and most straightforward prompts, providing a clear command or question.
#
# *   **Purpose:** To get a direct answer or a simple task completed.
# *   **Example:**
#     *   "Summarize the main points of the French Revolution."
#     *   "What is the capital of Japan?"
#     *   "Write a short poem about autumn."
#
# ### 2. Contextual Prompts
# These prompts provide background information or specific data that the LLM needs to consider when generating a response.
#
# *   **Purpose:** To ensure the output is relevant to a specific scenario or piece of information.
# *   **Example:**
#     *   "Given the following text: 'The company reported a 15% increase in Q3 revenue due to strong sales in the European market.', explain the primary reason for the revenue growth."
#     *   "I'm planning a trip to Rome in August. What kind of weather should I expect, and what are some indoor activities?"
#
# ### 3. Persona/Role-Playing Prompts
# These instruct the LLM to adopt a specific persona, character, or role before generating a response.
#
# *   **Purpose:** To tailor the tone, style, and content of the output to a particular voice or perspective.
# *   **Example:**
#     *   "Act as a seasoned travel agent and recommend a 7-day itinerary for a family vacation in Hawaii."
#     *   "You are a wise old wizard. Explain the concept of quantum physics in a way that a curious apprentice can understand."
#
# ### 4. Constraint-Based/Format Prompts
# These prompts specify rules, limitations, or desired output formats for the LLM.
#
# *   **Purpose:** To control the structure, length, or specific elements of the generated text.
# *   **Example:**
#     *   "Write a haiku about a blooming flower." (Constraint: 5-7-5 syllable structure)
#     *   "List three benefits of regular exercise, each in a separate bullet point." (Format: Bullet points)
#     *   "Generate a JSON object containing a user's name, email, and age." (Format: JSON)
#
# ### 5. Few-Shot Prompts (Example-Based Prompts)
# These prompts include one or more examples of input-output pairs to demonstrate the desired behavior or task. The LLM then generalizes from these examples.
#
# *   **Purpose:** To guide the LLM towards a specific pattern, style, or transformation, especially for complex or nuanced tasks.
# *   **Example:**
#     *   **Input:** "Translate English to French:\nHello -> Bonjour\nGoodbye -> Au revoir\nThank you -> ?"
#     *   **Input:** "Sentiment: 'I love this movie!' -> Positive\nSentiment: 'This is terrible.' -> Negative\nSentiment: 'It's okay, I guess.' -> ?"
#
# ### 6. Chain-of-Thought (CoT) Prompts
# These prompts encourage the LLM to show its reasoning process step-by-step before providing a final answer. This often improves accuracy for complex tasks.
#
# *   **Purpose:** To improve the model's ability to solve complex problems by breaking them down into intermediate steps, making the reasoning transparent.
# *   **Example:**
#     *   "Solve the following problem step-by-step: If a baker makes 20 loaves of bread per hour and works 8 hours a day, how many loaves does he make in 5 days?"
#     *   "Explain how photosynthesis works, detailing each stage of the process."
#
# ### 7. Negative Prompts (Exclusion Prompts)
# These prompts specify what the LLM *should not* include or do in its response. While often used in image generation, they can also apply to text.
#
# *   **Purpose:** To prevent undesired content or characteristics in the output.
# *   **Example:**
#     *   "Write a short story about a detective solving a mystery, but *do not* include any supernatural elements."
#     *   "Describe the ocean, but *avoid* mentioning fish or boats."
#
# ### 8. Iterative/Refinement Prompts
# These are follow-up prompts used in a conversational manner to refine or expand upon a previous AI response.
#
# *   **Purpose:** To fine-tune the output, ask for more detail, or correct previous generations.
# *   **Example:**
#     *   "That's good, now make it more concise."
#     *   "Can you elaborate on the third point?"
#     *   "Rewrite that paragraph in a more optimistic tone."
#
# ### 9. Retrieval Augmented Generation (RAG) Prompts
# While not a "type" of prompt in terms of its textual structure, RAG is a crucial *approach* that combines prompting with external knowledge retrieval. The prompt itself often includes or references the retrieved information.
#
# *   **Purpose:** To ground the LLM's response in specific, up-to-date, or proprietary data that it wasn't trained on, reducing hallucinations and improving factual accuracy.
# *   **Example:**
#     *   "Based on the following document about our company's Q2 earnings: [document text], what was the biggest challenge faced by the sales department?"
#     *   "Using the provided research paper on climate change [link or text], explain the impact of melting glaciers on sea levels."
#
# ---
#
# Understanding these different types of prompts empowers users to better interact with and leverage the capabilities of GenAI LLMs, transforming a simple text box into a powerful tool for creation, analysis, and problem-solving.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
