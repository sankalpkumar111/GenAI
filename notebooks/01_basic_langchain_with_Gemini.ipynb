# %%
# Langchain Model - Gemini AI - 
# DOTENV

# %% [markdown]
# ### Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
res=llm.invoke("Explain the theory of relativity in simple terms.")
print(res.content)
# Out:
# The Theory of Relativity, developed by Albert Einstein, isn't just one theory but two interconnected ones: **Special Relativity** (1905) and **General Relativity** (1915).
#
# At its core, relativity tells us that **space and time are not absolute and fixed, but are relative** to the observer's motion and the presence of mass/energy. They are intertwined into something called **spacetime**.
#
# Let's break it down simply:
#
# ---
#
# ### Part 1: Special Relativity (The Basics of Speed)
#
# This part deals with objects moving at **constant speeds** (no acceleration). It's built on two main ideas:
#
# 1.  **The Laws of Physics are the Same for Everyone:** No matter how fast you're moving at a constant speed, the fundamental laws of physics work the same way for you. (Imagine you're in a windowless train moving smoothly – you can't tell if you're moving or standing still without looking outside).
#
# 2.  **The Speed of Light is Constant for Everyone:** This is the weirdest but most crucial part. Light always travels at the exact same speed (about 300,000 kilometers per second or 186,000 miles per second) in a vacuum, no matter how fast the source of the light is moving or how fast you're moving to observe it. It's the universe's ultimate speed limit.
#
# **What these two ideas lead to (the "weird" stuff):**
#
# *   **Time Dilation:** If you're moving very fast relative to someone else, time will actually slow down for you compared to them. You'd age slower!
#     *   *Analogy:* Imagine a clock that works by light bouncing between two mirrors. If that clock is moving fast, the light has to travel a slightly longer diagonal path for each "tick," but since its speed is fixed, it takes *longer* to make a tick. So, time literally slows down.
# *   **Length Contraction:** Objects moving very fast appear shorter in the direction of their motion to a stationary observer.
# *   **Mass-Energy Equivalence (E=mc²):** This is the most famous equation! It says that mass and energy are interchangeable. A tiny bit of mass can be converted into a huge amount of energy (think atomic bombs or how the sun shines), and vice versa. 'c' is the speed of light, and 'c²' is an enormous number, meaning a little mass equals a lot of energy.
# *   **Cosmic Speed Limit:** Nothing with mass can travel at or faster than the speed of light. As an object gets closer to the speed of light, its mass increases, and it requires infinite energy to go any faster.
#
# **Important Note:** These effects only become noticeable at speeds close to the speed of light, which is why we don't experience them in our daily lives.
#
# ---
#
# ### Part 2: General Relativity (Gravity as Curvature)
#
# This part came later and deals with **acceleration and gravity**. Einstein realized that gravity isn't just a force pulling things down, but something much more profound:
#
# *   **Gravity is the Curvature of Spacetime:** Imagine spacetime as a giant, flexible trampoline.
#     *   Massive objects (like planets or stars) create "dents" or curves in this trampoline.
#     *   Smaller objects (like you, an apple, or even light) don't get "pulled" by a force; they simply follow the curves in spacetime created by the larger masses.
#     *   *Analogy:* If you roll a marble across a trampoline, and there's a bowling ball in the middle, the marble will curve inwards towards the bowling ball, not because the bowling ball is pulling it directly, but because the trampoline itself is curved.
#
# **What this leads to:**
#
# *   **Gravitational Lensing:** Light bends around massive objects. We see this when light from distant galaxies is bent by closer galaxies, creating distorted images. This was one of the first proofs of General Relativity.
# *   **Gravitational Time Dilation:** Time runs slower in stronger gravitational fields. So, a clock on Earth's surface runs slightly slower than a clock in orbit (like on GPS satellites). GPS systems actually have to account for this tiny difference to work accurately!
# *   **Black Holes:** These are regions where spacetime is so incredibly curved by an immense amount of mass that nothing, not even light, can escape.
# *   **Expanding Universe:** Einstein's equations predicted that the universe should either be expanding or contracting. Later observations confirmed it's expanding.
# *   **Gravitational Waves:** Ripples in spacetime itself, caused by extremely energetic events like colliding black holes. These were predicted by Einstein and directly detected for the first time in 2015.
#
# ---
#
# ### In a Nutshell:
#
# Relativity teaches us that **space and time are not separate, fixed backdrops** against which events happen. Instead, they are **flexible and interwoven into "spacetime,"** and their measurements depend on your motion and the presence of mass/energy. The speed of light is the ultimate constant, forcing everything else (time, length, mass) to adjust around it. And gravity isn't a mysterious force, but the **warping of this spacetime fabric by massive objects.**
