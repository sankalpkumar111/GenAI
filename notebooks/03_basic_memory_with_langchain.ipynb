# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
prompts=[{
    "role": "user",
    "content": "Hello my name is Sankalp kumar"
}]

res=llm.invoke(prompts)
res.content
# Out:
# 'Hello Sankalp Kumar! Nice to meet you.\n\nHow can I help you today?'

# %% [markdown]
# ### Manage history

# %%
history=[]
while True:
    query=input("User: ")
    history.append({"role":"user","content":query})
    print("User:",query)
    if query.lower() in ["exit","quit","bye"]:
        print("Exiting...")
        break
    res=llm.invoke(history)
    history.append({"role":"ai","content":res.content})
    
    print("AI: ",res.content,"\n")
# Out:
# User: Hello i want to know meaning of bye
# AI:  "Bye" is a very common and informal way to say **goodbye**.
#
# Here's a breakdown of its meaning and usage:
#
# 1.  **Core Meaning:** It's a word used to express **farewell** or **departure**. You say it when you are leaving, or when someone else is leaving, or when ending a conversation (like on the phone).
#
# 2.  **Origin:** It's a shortened form of "goodbye," which itself comes from the older phrase "God be with ye."
#
# 3.  **Usage:**
#     *   **Informal:** It's casual and friendly, suitable for almost any everyday situation with friends, family, colleagues, or even strangers in a quick interaction.
#     *   **Versatile:** You can use it when leaving a place, ending a phone call, or simply parting ways with someone.
#
# 4.  **Examples:**
#     *   "I have to go now, **bye**!"
#     *   "See you tomorrow! **Bye**!"
#     *   (On the phone) "Okay, talk to you later. **Bye**!"
#
# 5.  **Variations & Related Terms:**
#     *   **Goodbye:** The full form, slightly more formal than "bye" but still very common.
#     *   **Bye-bye:** Often used with children, or in a very affectionate/playful way.
#     *   **See you (later/soon):** Implies you'll meet again.
#     *   **Later! / Catch you later!:** More informal ways to say goodbye, also implying a future meeting.
#     *   **Take care:** A warm farewell that expresses concern for the other person's well-being.
#     *   **Farewell:** Much more formal, often implying a long or permanent separation.
#
# In essence, "bye" is one of the most common and simple ways to conclude an interaction and signify parting.
#
# User: thak you
# AI:  You're very welcome! I'm glad I could help.
#
# User: bye
# Exiting...
