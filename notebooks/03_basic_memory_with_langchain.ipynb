# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
prompts=[{
    "role": "user",
    "content": "Hello my name is Sankalp kumar"
}]

res=llm.invoke(prompts)
res.content
# Out:
# "Hello Sankalp Kumar! It's nice to meet you."

# %% [markdown]
# ### Manage history

# %%
history=[]
while True:
    query=input("User: ")
    history.append({"role":"user","content":query})
    print("User:",query)
    if query.lower() in ["exit","quit","bye"]:
        print("Exiting...")
        break
    res=llm.invoke(history)
    history.append({"role":"ai","content":res.content})
    
    print("AI: ",res.content,"\n")
# Out:
# User: My name is sankalp
# AI:  Hello Sankalp! It's nice to meet you.
#
# How can I assist you today?
#
# User: what is my name?
# AI:  Your name is Sankalp.
#
# User: Where is lnct college?
# AI:  LNCT College (Lakshmi Narain College of Technology) is primarily located in **Bhopal, Madhya Pradesh, India.**
#
# It is a well-known institution and forms part of the LNCT Group of Colleges, which also has other campuses and institutions in cities like:
#
# *   **Bhopal** (main campus and several others)
# *   **Indore**
# *   **Jabalpur**
# *   **Gwalior**
#
# So, while the main and most recognized campus is in Bhopal, there are other branches. If you're looking for a specific one, letting me know which city might help!
#
# User: exit
# Exiting...
