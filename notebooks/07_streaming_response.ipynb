# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash",streaming=True)

# %%
q=input()

# %%
res=llm.stream(q)
for chunk in res:
    print(chunk.content)
# Out:
# Python is a **high-level, interpreted,
#  general-purpose programming language** that is widely used for a vast array of applications, from web development to artificial intelligence.
#
# Here's a breakdown of what that means and why it's so popular:
#
# ---
#
# ### Key Characteristics of Python
#
#
# 1.  **High-Level:** You don't have to worry about low-level details like managing computer memory or interacting directly with hardware. Python handles these complexities, allowing you to focus on solving problems.
# 2.  **Interpre
# ted:** Unlike compiled languages (like C++ or Java), Python code is executed line by line by an interpreter at runtime, rather than being fully translated into machine code before execution. This makes the development cycle faster and debugging easier.
# 3
# .  **General-Purpose:** It's not designed for one specific type of task. You can use Python for almost anything!
# 4.  **Readability:** One of Python's core philosophies is code readability. It uses
#  an elegant, English-like syntax with clear indentation (rather than curly braces) to define code blocks, making it easier to learn, write, and understand than many other languages.
# 5.  **Object-Oriented:** Python fully
#  supports object-oriented programming (OOP) paradigms, which allow you to organize your code into reusable blueprints (objects and classes).
# 6.  **Dynamically Typed:** You don't need to declare the type of a variable (e.g.,
#  integer, string) when you create it. Python figures it out at runtime. This offers flexibility but can sometimes lead to runtime errors if types are misused.
# 7.  **Extensive Standard Library:** Python comes with a huge collection of modules
#  and packages "out of the box" that provide functionalities for things like file I/O, network communication, mathematical operations, and more. This "batteries included" approach saves developers a lot of time.
# 8.  **Large Ecosystem
#  & Community:** Beyond the standard library, there's a massive ecosystem of third-party libraries (available via PyPI – the Python Package Index) and a vibrant, supportive community of developers. If you need to do something, chances are someone has
#  already written a library for it.
# 9.  **Cross-Platform:** Python code can run on various operating systems (Windows, macOS, Linux, etc.) without modification, thanks to the Python interpreter being available on these platforms.
#
# ---
#
#
# ### What is Python Used For?
#
# Python's versatility makes it a favorite in many fields:
#
# *   **Web Development:** Frameworks like Django and Flask are popular for building robust web applications and APIs.
# *   **Data Science &
#  Machine Learning (AI):** This is where Python truly shines. Libraries like NumPy, Pandas, Scikit-learn, TensorFlow, and PyTorch have made Python the de facto language for data analysis, data visualization, machine learning, and artificial intelligence.
#
# *   **Automation & Scripting:** Its simple syntax makes it ideal for writing scripts to automate repetitive tasks, manage system operations, or process files.
# *   **DevOps:** Used for automating infrastructure management, deployment, and monitoring
# .
# *   **Desktop GUIs:** Libraries like Tkinter, PyQt, and Kivy allow for the creation of desktop applications.
# *   **Scientific & Numeric Computing:** Widely used in academia and research for complex calculations and simulations.
#
# *   **Education:** Its simplicity and readability make it an excellent language for teaching programming concepts to beginners.
# *   **Game Development:** While not its primary use, libraries like Pygame can be used to develop simple games.
#
#
# ---
#
# ### A Simple Python Example
#
# To give you a taste of its simplicity, here's the classic "Hello, World!" program in Python:
#
# ```python
# # This is a comment - Python ignores lines starting with #
# message
#  = "Hello, Python!"
# print(message)
# ```
#
# When you run this code, it will simply output: `Hello, Python!`
#
# ---
#
# ### Why is Python so popular?
#
# *   **Ease of Learning:**
#  Its clear syntax makes it very approachable for beginners.
# *   **Increased Productivity:** Developers can write less code to achieve more, leading to faster development cycles.
# *   **Versatility:** Its "general-purpose" nature means it can
#  be applied to almost any problem.
# *   **Rich Ecosystem:** The vast array of libraries and frameworks means you rarely have to start from scratch.
# *   **Strong Community Support:** Help and resources are always readily available.
#
# In
#  essence, Python is a powerful, versatile, and beginner-friendly language that has become indispensable in many modern technology fields due to its focus on readability, extensive libraries, and strong community support.
