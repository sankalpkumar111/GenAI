# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash",streaming=True)

# %%
q="What is the Gen Ai"

# %%
res=llm.stream(q)
for chunk in res:
    print(chunk.content)
# Out:
# **Gen AI** stands for **Generative Artificial Intelligence**.
#
# It's a branch of AI that focuses
#  on creating **new, original content** rather than just analyzing or classifying existing data. Unlike traditional AI that might identify a cat in an image or predict stock prices, Gen AI can *generate* an image of a cat that's never existed
#  before, write a story, compose music, or even create lines of code.
#
# ### How Gen AI Works (Simplified)
#
# 1.  **Training Data:** Gen AI models are trained on massive datasets of existing content (text, images, audio
# , video, code, etc.).
# 2.  **Pattern Recognition:** During training, the AI learns the underlying patterns, structures, styles, and relationships within that data. It understands how words form sentences, how colors and shapes form objects
# , or how musical notes create melodies.
# ...
