# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text='''Today, I want to speak from the heart about three pillars that define the future of our nation:
our youth, our education system, and our farmers.'''

# %%
splitter=RecursiveCharacterTextSplitter(chunk_size=25,chunk_overlap=10)

# %%
chunks=splitter.split_text(text)

# %%
chunks
# Out:
# ['Today, I want to speak',
#  'to speak from the heart',
#  'the heart about three',
#  'three pillars that',
#  'that define the future',
#  'future of our nation:',
#  'our youth, our education',
#  'education system, and',
#  'and our farmers.']

# %% [markdown]
# ### Document Text Loadder

# %%
from langchain_community.document_loaders import TextLoader,PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
loader =TextLoader("../data/speech.txt",encoding="utf-8")
text=loader.load()

# %%
pdfloader=PyPDFLoader("../data/medical_report.pdf")
pdfs=pdfloader.load()

# %%
splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)

# %%
text_chunk=splitter.split_documents(text)
len(text_chunk)
# Out:
# 2

# %%
pdf_chunk=splitter.split_documents(pdfs)    
len(pdf_chunk)
# Out:
# 26
