# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
documents = [
    "Machine learning is a subset of artificial intelligence",
    "Deep learning uses neural networks with multiple layers",
    "Python is a programming language popular for data science",
    "India won the cricket world cup in 2011",
    "AI models can understand and generate human language"
]

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-2-preview")

# %%
vector = embeddings.embed_documents(documents)

# %% [markdown]
# ### Store Vector Embeddings into Vector DB

# %%
from langchain_chroma import Chroma

# %%
vector_stored=Chroma.from_texts(texts=documents, embedding=embeddings, persist_directory="./vector_db")

# %%
query="Machine Learning"
result=vector_stored.similarity_search(query,k=2)
result
# Out:
# [Document(id='9241ee44-25c4-48d2-890c-9c96c9b4e9cf', metadata={}, page_content='Machine learning is a subset of artificial intelligence'),
#  Document(id='a652037b-61fa-4486-8484-3e9bd0c985b4', metadata={}, page_content='Deep learning uses neural networks with multiple layers')]
