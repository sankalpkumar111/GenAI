# %%
from dotenv import load_dotenv  
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm=ChatGroq(model="openai/gpt-oss-20b")

# %%
res=llm.invoke("What is Gen AI?")
res.content
# Out:
# '## Generative AI (Gen AI) – A Quick Primer\n\n### 1. What is it?\n\n**Generative AI** refers to a family of artificial‑intelligence systems that *create* new content—text, images, audio, video, code, and more—rather than just analyzing or classifying existing data.  \nThe “generative” part comes from the model’s ability to *generate* data that is statistically similar to the patterns it learned during training.\n\n### 2. Core Technologies\n\n| Technology | What it does | Typical Models |\n|------------|--------------|----------------|\n| **Transformers** | Sequence‑to‑sequence modeling (language, multimodal) | GPT‑4, BERT, T5 |\n| **Diffusion Models** | Iteratively denoise random noise to produce images/audio | Stable Diffusion, DALL‑E 2 |\n| **Variational Autoencoders (VAEs)** | Encode data to a latent space, then decode to generate | VAE‑GAN hybrids |\n| **Generative Adversarial Networks (GANs)** | Two networks (generator & discriminator) compete to produce realistic samples | StyleGAN, BigGAN |\n| **Reinforcement Learning from Human Feedback (RLHF)** | Fine‑tunes models to align with human preferences | ChatGPT, Claude |\n\nThese building blocks can be mixed: e.g., a transformer that generates text prompts fed into a diffusion model that creates an image.\n\n### 3. How Do They Work?\n\n1. **Training**  \n   - **Data**: Large corpora (text, images, code, etc.).  \n   - **Objective**: Learn the probability distribution of the data.  \n   - **Loss Function**: Cross‑entropy for language, reconstruction loss for VAEs, adversarial loss for GANs, diffusion loss for diffusion models.\n\n2. **Generation**  \n   - **Sampling**: Start from a seed (e.g., a prompt or random noise).  \n   - **Decoding**: Apply the trained model to produce new samples, often using techniques like beam search, nucleus sampling, or stochastic denoising.\n\n3. **Fine‑Tuning & Alignment**  \n   - **Supervised fine‑tuning** on task‑specific data.  \n   - **RLHF** to align outputs with human values and reduce harmful or nonsensical outputs.\n\n### 4. What Can It Do?\n\n| Domain | Examples |\n|--------|----------|\n| **Text** | Writing articles, summarizing documents, answering questions, coding, translating, creative storytelling |\n| **Images** | Photo‑realistic art, style transfer, inpainting, upscaling, design mockups |\n| **Audio** | Music generation, voice cloning, speech synthesis, sound effects |\n| **Video** | Short‑form video creation, animation, frame interpolation |\n| **Code** | Auto‑completion, bug detection, algorithm generation |\n| **Multimodal** | Text‑to‑image, image captioning, image‑to‑text, audio‑to‑text, etc. |\n\n### 5. Why It Matters\n\n| Benefit | Explanation |\n|---------|-------------|\n| **Speed & Scale** | Generates content in seconds that would take humans hours. |\n| **Creativity & Ideation** | Provides fresh ideas, drafts, or prototypes for artists, designers, writers. |\n| **Accessibility** | Lowers barriers for non‑experts (e.g., a small business can create marketing copy or graphics). |\n| **Automation** | Powers chatbots, virtual assistants, content moderation, and more. |\n| **Research & Discovery** | Helps generate hypotheses, simulate experiments, or synthesize literature. |\n\n### 6. Key Challenges & Considerations\n\n| Challenge | Impact | Mitigation |\n|-----------|--------|------------|\n| **Hallucinations** | Models may produce plausible but incorrect facts. | Fact‑checking prompts, grounding in external knowledge bases. |\n| **Bias & Fairness** | Learned biases can propagate stereotypes or unfair outcomes. | Diverse training data, bias‑audit, post‑processing filters. |\n| **Misuse** | Deepfakes, disinformation, plagiarism. | Detection tools, usage policies, watermarking. |\n| **Computational Cost** | Training large models requires massive GPU clusters. | Efficient architectures, distillation, federated learning. |\n| **Interpretability** | Hard to understand why a model produced a particular output. | Attention visu ...
